# %% [markdown]
# # 파이썬 크롤링 하기

# %% [markdown]
# ## - requests 모듈사용
# requests 모듈을 통해 웹페이지를 가져올 수 있다
#
#  - 모듈설명 : https://pypi.org/project/requests/

# %%
import requests
url = "https://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&oid=005&listType=paper&date=20210505"

# %%
webpage = requests.get(url)
print(r.request.headers)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\http\client.py in getresponse(self)
#    1344             try:
# -> 1345                 response.begin()
#    1346             except ConnectionError:
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\http\client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\http\client.py in getresponse(self)
#    1344             try:
# -> 1345                 response.begin()
#    1346             except ConnectionError:
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\http\client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-3b35e3eca46c> in <module>
# ----> 1 webpage = requests.get(url)
#       2 print(r.request.headers)
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\users\quoti\appdata\local\programs\python\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# ## - 크롤링 봇 정책
#  - `https://news.naver.com/robots.txt`
#
# ```
# User-agent: Yeti
# Allow: /main/imagemontage
# Disallow: /
# User-agent: *
# Disallow: /
# ```
#  - 크롤링 결과 : `Connection aborted`
#
# 몇몇 페이지는 서버 과부하를 줄이기 위해 크롤링을 하지 못하게 막아놓았는데
#
# 유저가 브라우저를 통해 직접 접근했는지 아니면 크롤링 도구를 이용해 접근했는지 판단하는 기준은 바로 User-Agent이다.

# %%
webpage = requests.get("https://naver.com")
print(webpage)
# Out:
# <Response [200]>

# %%
webpage.request.headers
# Out:
# {'User-Agent': 'python-requests/2.25.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %% [markdown]
# 크롤링으로 접근이 허가된 네이버 메인페이지에 접속하고 난 후에 User-Agent의 내용을 보면 `python-requests/2.25.1`로 되어 있다.
#
# 이 부분을 수정하여 브라우저를 사용해서 접근하는 것처럼 만들면 된다.

# %%
headers = { "User-Agent": "user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36" } 
webpage = requests.get(url, headers=headers)
webpage.text
# Out:
# '\r\n\r\n\r\n\r\n<!DOCTYPE HTML>\r\n<html lang="ko">\r\n<head>\r\n<meta charset="euc-kr">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="referrer" contents="always">\r\n<meta http-equiv="refresh" content="600" />\r\n<meta name="viewport" content="width=1106" />\r\n\r\n    \r\n    \r\n        \r\n            \r\n            \r\n            \r\n                \r\n                \r\n                \r\n                \r\n            \r\n            \r\n            \r\n        \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n\r\n<meta property="og:title"       content="국민일보 언론사홈">\r\n<meta property="og:type"        content="website">\r\n<meta property="og:url"         content="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&oid=005">\r\n<meta property="og:image"       content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png"/>\r\n<meta property="og:description" content="언론사 주요 뉴스와 속보를 만나볼 수 있습니다.">\r\n<meta property="og:article:author"\tcontent="네이버"/>\r\n\r\n<meta name="twitter:card"\t\tcontent="summary">\r\n<meta name="twitter:title"\t\tcontent="국민일보 언론사홈">\r\n<meta name="twitter:site"       content="네이버 뉴스">\r\n<meta name="twitter:creator"    content="네이버 뉴스">\r\n<meta name="twitter:image"\t\tcontent="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png">\r\n<meta name="twitter:description" content="언론사 주요 뉴스와 속보를 만나볼 수 있습니다.">\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<title>신문게재기사, \r\n\t\t\t국민일보 : 네이버 뉴스\t</title>\r\n<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" />\r\n\r\n\r\n\r\n\t\r\n\t\r\n\t\r\n\r\n\n\t\n\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20210415_124541/css/common.css"/>\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20210415_124541/css/news.css"/>\n\t\t\n\t\t\n\t\n\t\n\n\r\n\r\n\r\n\r\n\r\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20210415_124541/js/news.jindo.js" charset="euc-kr"></script>\r\n\r\n\r\n\n\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20210415_124541/js/news.jquery.js" charset="utf-8"></script>\n\n\n\n\n\n\t\n\t\n\t\t\n\t\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\t\n\t\n\t\n\n\n\n\n\t\n\t\t\n\t\t\t\n\t\t\n\t\t\n\t\n\n\n\n<script type="text/javascript">\ndocument.domain=\'naver.com\';\nvar _MAIN_NEWS_MENU_ID=\'sec\';\nvar _MAIN_NEWS_SECTION_ID=\'\';\nvar ccsrv=\'cc.naver.com\';\nvar g_ssc=\'news.press\';\nwindow.nsc = g_ssc; \nvar gnb_service=\'news\';\nvar gnb_logout=encodeURIComponent(location.href);\nvar gnb_template=\'gnb_utf8\';\nvar gnb_brightness = 1;\nvar gnb_one_naver = 1;\nvar gnb_searchbox=\'on\';\nvar gnb_shortnick=\'on\';\n\nvar gnb_timestamp = "2021050600";\n</script>\n\n\n\n\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20210415_124541/js/news.service.js" charset="euc-kr"></script>\n\n\n\n\n\r\n</head>\r\n\r\n<body>\r\n\t<div id="wrap">\r\n\t\t<!-- 광고적용 태그 추가 -->\r\n\t\t<div id="da_base"></div>\r\n\t\t<div id="da_stake"></div>\r\n\t\t\r\n\r\n\r\n<div id="header" class="header">\r\n\t\r\n\t<div id="u_skip">\r\n\t\t<a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>\r\n\t\t<a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>\r\n\t</div>\r\n\t\r\n\r\n\t<div class="snb_area">\r\n\t\t<div class="snb_inner">\r\n\t\t\t<div class="gnb_wrap">\r\n   <!-- GNB 마크업 -->\r\n   <div id="gnb"></div>\r\n   <!-- //GNB 마크업 -->\r\n</div>\r\n\t\t\t\r\n\r\n\r\n<div id="snb_wrap">\r\n    <h1>\r\n        <a href="https://www.naver.com/" class="h_logo nclicks(STA.naver)"><span class="blind">NAVER</span></a>\r\n        <a href="/" class="h_news ...

# %%
webpage.headers
# Out:
# {'date': 'Wed, 05 May 2021 15:09:17 GMT', 'cache-control': 'no-cache', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'set-cookie': 'JSESSIONID=2BE86D60D04065A64799F4F93A66F6B8; Path=/main; HttpOnly', 'content-language': 'ko-KR', 'vary': 'Accept-Encoding', 'content-encoding': 'gzip', 'transfer-encoding': 'chunked', 'content-type': 'text/html;charset=EUC-KR', 'referrer-policy': 'unsafe-url', 'server': 'nfront'}

# %% [markdown]
# ## - BeautifulSoup 모듈 사용하기
# 외부 모듈을 이용해 편하게 크롤링한 정보를
#
# ```pip
# pip install bs4
# ```
#
# 사용법 : https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(webpage.text, 'html.parser')

# %% [markdown]
# ### * 크롤링을 통해 가져온 페이지를 파일 형식으로 저장하기

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta contents="always" name="referrer"/>
#   <meta content="600" http-equiv="refresh">
#    <meta content="width=1106" name="viewport">
#     <meta content="국민일보 언론사홈" property="og:title"/>
#     <meta content="website" property="og:type"/>
#     <meta content="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=005" property="og:url"/>
#     <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
#      <meta content="언론사 주요 뉴스와 속보를 만나볼 수 있습니다." property="og:description"/>
#      <meta content="네이버" property="og:article:author">
#       <meta content="summary" name="twitter:card"/>
#       <meta content="국민일보 언론사홈" name="twitter:title"/>
#       <meta content="네이버 뉴스" name="twitter:site"/>
#       <meta content="네이버 뉴스" name="twitter:creator"/>
#       <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" name="twitter:image"/>
#       <meta content="언론사 주요 뉴스와 속보를 만나볼 수 있습니다." name="twitter:description"/>
#       <title>
#        신문게재기사,
# 			국민일보 : 네이버 뉴스
#       </title>
#       <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#       <link href="https://ssl.pstatic.net/static.news/pnews/resources/20210415_124541/css/common.css" rel="stylesheet" type="text/css"/>
#       <link href="https://ssl.pstatic.net/static.news/pnews/resources/20210415_124541/css/news.css" rel="stylesheet" type="text/css"/>
#       <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20210415_124541/js/news.jindo.js" type="text/javascript">
#       </script>
#       <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20210415_124541/js/news.jquery.js" type="text/javascript">
#       </script>
#       <script type="text/javascript">
#        document.domain='naver.com';
# var _MAIN_NEWS_MENU_ID='sec';
# var _MAIN_NEWS_SECTION_ID='';
# var ccsrv='cc.naver.com';
# var g_ssc='news.press';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 1;
# var gnb_one_naver = 1;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "2021050600";
#       </script>
#       <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20210415_124541/js/news.service.js" type="text/javascript">
#       </script>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div id="wrap">
#    <!-- 광고적용 태그 추가 -->
#    <div id="da_base">
#    </div>
#    <div id="da_stake">
#    </div>
#    <div class="header" id="header">
#     <div id="u_skip">
#      <a href="#lnb" tabindex="1">
#       <span>
#        메인 메뉴로 바로가기
#       </span>
#      </a>
#      <a href="#main_content" tabindex="2">
#       <span>
#        본문으로 바로가기
#       </span>
#      </a>
#     </div>
#     <div class="snb_area">
#      <div class="snb_inner">
#       <div class="gnb_wrap">
#        <!-- GNB 마크업 -->
#        <div id="gnb">
#        </div>
#        <!-- //GNB 마크업 -->
#       </div>
#       <div id="snb_wrap">
#        <h1>
#         <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/">
#          <span class="blind">
#           NAVER
#          </span>
#         </a>
#         <a class="h_news nclicks(STA.news)" href="/">
#          <span class="blind">
#           뉴스
#          </span>
#         </a>
#        </h1>
#        <ul class="snb_related_service">
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="nclicks(STA.enter)" href="https://entertain.naver.com/home">
#           <img alt="TV연예" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_entertain.png" width="52"/>
#          </a>
#         </li>
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="nclicks(STA.sports)" href="https://sports.news.naver.com">
#           <img alt="스포츠" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_sports.png" width="48"/>
#          </a>
#         </li>
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="nclicks(STA.newsstand)" href="https://newsstand.naver.com">
#           <img alt="뉴스스탠드" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_newsstand.png" width="77"/>
#          </a>
#         </li>
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="nclicks(STA.weather)" href="https://weather.naver.com">
#           <img alt="날씨" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_weather.png" width="31"/>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="lnb_area">
#      <div class="lnb_inner">
#       <div class="lnb_menu" id="lnb">
#        <ul>
#         <li>
#          <a class="nclicks(LNB.home)" href="/main/home.nhn">
#           <span class="tx">
#            뉴스홈
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(LNB.flash)" href="/main/list.nhn?mode=LSD&amp;mid=sec&amp;sid1=001">
#           <span class="tx">
#            속보
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(LNB.pol)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=100">
#           <span class="tx">
#            정치
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(LNB.eco)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101">
#           <span class="tx">
#            경제
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(LNB.soc)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=102">
#           <span class="tx">
#            사회
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(LNB.lif)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=103">
#           <span class="tx">
#            생활/문화
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(LNB.wor)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=104">
#           <span class="tx">
#            세계
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(LNB.sci)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=105">
#           <span class="tx">
#            IT/과학
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(LNB.opi)" href="/main/opinion/home.nhn">
#           <span class="tx">
#            오피니언
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(LNB.pho)" href="/main/photo/index.nhn?mid=pho">
#           <span class="tx">
#            포토
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(LNB.tv)" href="/main/tv/index.nhn?mid=tvh">
#           <span class="tx">
#            TV
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(LNB.ranking)" href="/main/ranking/popularDay.nhn?mid=etc&amp;sid1=111">
#           <span class="tx">
#            랭킹뉴스
#           </span>
#          </a>
#         </li>
#        </ul>
#        <form accept-charset="UTF-8" action="https://search.naver.com/search.naver" id="lnb.searchForm" method="get" name="lnb_searchForm" target="_blank">
#         <fieldset>
#          <legend>
#           뉴스 검색
#          </legend>
#          <input accesskey="s" class="text_index" name="query" style="ime-mode:active;" title="뉴스 검색" type="text"/>
#          <input name="where" type="hidden" value="news"/>
#          <input name="ie" type="hidden" value="utf8"/>
#          <input name="sm" type="hidden" value="nws_hty"/>
#          <button class="btn_search_lnb nclicks(LNB.search)" type="submit">
#           <span class="tx">
#            <span class="blind">
#             검색
#            </span>
#           </span>
#          </button>
#         </fieldset>
#        </form>
#       </div>
#      </div>
#     </div>
#     <div class="lnb">
#      <span class="lnb_date">
#       <strong>
#        05
#       </strong>
#       .
#       <strong>
#        06
#       </strong>
#       <span class="day">
#        (목)
#       </span>
#      </span>
#      <ul class="lnb_side" tabindex="0">
#       <li>
#        <a class="nclicks(nct.right1)" href="https://news.naver.com/main/factcheck/main.nhn" title="팩트체크">
#         팩트체크
#        </a>
#       </li>
#       <li>
#        <a class="nclicks(nct.right2)" href="https://media.naver.com/channel/settings.nhn  " target="_blank" title="언론사 구독 ">
#         언론사 구독
#        </a>
#       </li>
#       <li>
#        <a class="nclicks(nct.right3)" href="https://news.naver.com/main/officeList.nhn" title="언론사 뉴스">
#         언론사 뉴스
#        </a>
#       </li>
#       <li class="end">
#        <a class="nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">
#         라이브러리
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <hr/>
#    <table cellpadding="0" cellspacing="0" class="container">
#     <caption class="blind">
#      기사목록
#     </caption>
#     <colgroup>
#      <col class="col_snb"/>
#      <col class="col_content"/>
#      <col class="col_aside"/>
#     </colgroup>
#     <tr>
#      <td class="snb">
#       <div class="snb" id="snb">
#        <h2 class="h2">
#         <a class="nclicks(lmn_prs.home)" href="/main/officeList.nhn">
#          언론사 뉴스
#         </a>
#        </h2>
#        <ul class="nav">
#         <li class="on">
#          <a class="nclicks(lmn_prs.tog)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=032">
#           종합
#           <span class="blind">
#            선택됨
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(lmn_prs.bro)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=421">
#           방송/통신
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(lmn_prs.eco)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=009">
#           경제
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(lmn_prs.int)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=079">
#           인터넷
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(lmn_prs.sci)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=138">
#           IT
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(lmn_prs.pho)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=348">
#           포토
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(lmn_prs.mag)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=145">
#           매거진
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(lmn_prs.pro)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=127">
#           전문지
#          </a>
#         </li>
#         <li>
#          <a class="nclicks(lmn_prs.reg)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=087">
#           지역
#          </a>
#         </li>
#        </ul>
#       </div>
#      </td>
#      <td class="content">
#       <div class="content" id="main_content">
#        <div class="list_header newsflash_header2">
#         <h3>
#          종합
#         </h3>
#         <div class="topbox_type4">
#          <div>
#           <ul class="massmedia">
#            <li>
#             <a class="nclicks(cnt_press)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=032">
#              경향신문
#             </a>
#             <i class="picon">
#              신문
#             </i>
#            </li>
#            <li>
#             <a class="visit on nclicks(cnt_press)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=005">
#              국민일보
#             </a>
#             <i class="picon">
#              신문
#             </i>
#            </li>
#            <li>
#             <a class="nclicks(cnt_press)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=020">
#              동아일보
#             </a>
#             <i class="picon">
#              신문
#             </i>
#            </li>
#            <li>
#             <a class="nclicks(cnt_press)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=021">
#              문화일보
#             </a>
#             <i class="picon">
#              신문
#             </i>
#            </li>
#            <li>
#             <a class="nclicks(cnt_press)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=081">
#              서울신문
#             </a>
#             <i class="picon">
#              신문
#             </i>
#            </li>
#            <li>
#             <a class="nclicks(cnt_press)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=022">
#              세계일보
#             </a>
#             <i class="picon">
#              신문
#             </i>
#            </li>
#            <li>
#             <a class="nclicks(cnt_press)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=023">
#              조선일보
#             </a>
#             <i class="picon">
#              신문
#             </i>
#            </li>
#            <li>
#             <a class="nclicks(cnt_press)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=025">
#              중앙일보
#             </a>
#             <i class="picon">
#              신문
#             </i>
#            </li>
#            <li>
#             <a class="nclicks(cnt_press)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=028">
#              한겨레
#             </a>
#             <i class="picon">
#              신문
#             </i>
#            </li>
#            <li>
#             <a class="nclicks(cnt_press)" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;oid=469">
#              한국일보
#             </a>
#             <i class="picon">
#              신문
#             </i>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="list_body newsflash_body">
#         <div class="newsflash_header3">
#          <h3>
#           국민일보
#          </h3>
#          <div class="view_type">
#           <a class="newsp_on nclicks(fls.vtype)" href="list.nhn;jsessionid=2BE86D60D04065A64799F4F93A66F6B8?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210505" title="신문에 게재된 기사만 보실 수 있습니다.">
#            신문게재기사만
#           </a>
#           <span class="bar">
#            |
#           </span>
#           <a class="tit_off nclicks(fls.vtype)" href="list.nhn;jsessionid=2BE86D60D04065A64799F4F93A66F6B8?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=title&amp;date=20210505">
#            제목형
#           </a>
#           <a class="sum_off nclicks(fls.vtype)" href="list.nhn;jsessionid=2BE86D60D04065A64799F4F93A66F6B8?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=summary&amp;date=20210505">
#            요약형
#           </a>
#           <a class="photo_off nclicks(fls.vtype)" href="list.nhn;jsessionid=2BE86D60D04065A64799F4F93A66F6B8?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=photo&amp;type=3&amp;date=20210505">
#            포토만
#           </a>
#          </div>
#         </div>
#         <div class="calendar_date">
#          <a class="btn pre" href="/main/list.nhn;jsessionid=2BE86D60D04065A64799F4F93A66F6B8?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210504" title="이전">
#           <span>
#            이전
#           </span>
#          </a>
#          <span class="c_date">
#           2021.05.05.
#          </span>
#          <a class="btn next" href="/main/list.nhn;jsessionid=2BE86D60D04065A64799F4F93A66F6B8?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210506" title="다음">
#           <span>
#            다음
#           </span>
#          </a>
#          <div class="cal_area">
#           <a class="btn cal" href="#" id="u.c.button" title="달력보기">
#            <span>
#             달력보기
#            </span>
#           </a>
#           <div class="layer01 layer03" id="u.c.layer">
#            <div class="calendar layer01_content">
#             <div class="calendar_inner">
#              <div class="head">
#               <div>
#                <div class="skin01">
#                 <select id="u.c.year.select" style="display:none;" title="년도 선택">
#                 </select>
#                 <div class="selectbox" id="u.c.year.div">
#                  <a class="box" href="#">
#                   <span class="label">
#                   </span>
#                   <span class="button">
#                    <span class="blind">
#                     연도선택
#                    </span>
#                   </span>
#                  </a>
#                  <div class="list scrollbox" style="overflow: hidden; z-index: 999;">
#                   <div class="content" style="overflow: hidden; margin-right: 0px;">
#                    <ul style="margin: 0pt; padding: 0pt; position: relative; left: 0px; top: 0px;">
#                    </ul>
#                   </div>
#                   <div class="scrollbar-v">
#                    <div class="thumb-v" style="top: 12px;">
#                     <span class="thumb-body" style="height: 10px;">
#                     </span>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="body">
#               <div class="calendarbox">
#                <div class="choose">
#                 <span class="_month">
#                 </span>
#                 <a class="prev" href="#" title="이전달">
#                  <span>
#                   이전달
#                  </span>
#                 </a>
#                 <a class="next" href="#" title="다음달">
#                  <span>
#                   다음달
#                  </span>
#                 </a>
#                </div>
#                <div class="tbl">
#                 <table cellspacing="0">
#                  <caption>
#                   달력
#                  </caption>
#                  <col width="33"/>
#                  <col width="33"/>
#                  <col width="33"/>
#                  <col width="33"/>
#                  <col width="33"/>
#                  <col width="33"/>
#                  <col width="33"/>
#                  <thead>
#                   <tr>
#                    <th scope="col">
#                     일
#                    </th>
#                    <th scope="col">
#                     월
#                    </th>
#                    <th scope="col">
#                     화
#                    </th>
#                    <th scope="col">
#                     수
#                    </th>
#                    <th scope="col">
#                     목
#                    </th>
#                    <th scope="col">
#                     금
#                    </th>
#                    <th scope="col">
#                     토
#                    </th>
#                   </tr>
#                  </thead>
#                  <tbody>
#                  </tbody>
#                 </table>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <a class="btn now" href="/main/list.nhn;jsessionid=2BE86D60D04065A64799F4F93A66F6B8?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper" title="오늘">
#           <span>
#            오늘
#           </span>
#          </a>
#         </div>
#         <div class="topbox_type6">
#          <div>
#           <ul>
#            <li>
#             <a class="on nclicks(cnt_order)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210505&amp;page=1">
#              1~10면
#             </a>
#            </li>
#            <li>
#             <a class="nclicks(cnt_order)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210505&amp;page=2">
#              11~20면
#             </a>
#            </li>
#            <li>
#             <a class="nclicks(cnt_order)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210505&amp;page=3">
#              21~30면
#             </a>
#            </li>
#            <li>
#             <a class="nclicks(cnt_order)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210505&amp;page=4">
#              31~40면
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <h4 class="paper_h4">
#          1면
#         </h4>
#         <ul class="type13 firstlist">
#          <li>
#           <dl>
#            <dt class="photo">
#             <a class="nclicks(cnt_papaerart1)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436553">
#              <img alt="후보 확정까지 4개월… 대선 행보 초읽기" height="90" src="https://imgnews.pstatic.net/image/origin/005/2021/05/05/1436553.jpg?type=nf132_90" width="132"/>
#             </a>
#            </dt>
#            <dt>
#             <a class="nclicks(cnt_papaerart3)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436553">
#              후보 확정까지 4개월… 대선 행보 초읽기
#             </a>
#            </dt>
#            <dd>
#             <span class="lede 88">
#              더불어민주당 신임 지도부 구성이 완료되면서 그동안 대기 중이던 여당 대선 주자들이 일제히 출발선에 섰다. 경선을 통해 9월 당의 공식후보 확정까지 남아 있는  …
#             </span>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 1면의 TOP기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              1면
#              <i class="icon_top">
#               TOP
#              </i>
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:04
#             </span>
#            </dd>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436525">
#              [포토] 코로나에도… 즐거운 동심
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 1면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              1면
#             </span>
#             <span class="date">
#              2021.05.05. 오전 12:11
#             </span>
#            </dt>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436596">
#              가족동반 출장엔 “관행” 밀수 의혹은 “집에서 사용”… 황당 해명
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 1면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              1면
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:09
#             </span>
#            </dt>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436602">
#              변이 바이러스 국내 감염자 1499명 ‘비상’
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 1면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              1면
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:09
#             </span>
#            </dt>
#           </dl>
#          </li>
#         </ul>
#         <h4 class="paper_h4">
#          2면
#         </h4>
#         <ul class="type13 firstlist">
#          <li>
#           <dl>
#            <dt class="photo">
#             <a class="nclicks(cnt_papaerart1)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436555">
#              <img alt="27년 동행 끝 ‘천문학적 결별’… 재산 146조 어떻게 나눌까" height="90" src="https://imgnews.pstatic.net/image/origin/005/2021/05/05/1436555.jpg?type=nf132_90" width="132"/>
#             </a>
#            </dt>
#            <dt>
#             <a class="nclicks(cnt_papaerart3)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436555">
#              27년 동행 끝 ‘천문학적 결별’… 재산 146조 어떻게 나눌까
#             </a>
#            </dt>
#            <dd>
#             <span class="lede 88">
#              세계 최대 소프트웨어 업체 마이크로소프트(MS)의 공동창업자 빌 게이츠(65)가 아내 멀린다 게이츠(56)와 결혼 27년 만에 이혼을 선언했다. 두 사람이 공 …
#             </span>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 2면의 TOP기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              2면
#              <i class="icon_top">
#               TOP
#              </i>
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:04
#             </span>
#            </dd>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436497">
#              [국민만평-서민호 화백] 2021년 5월 5일
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 2면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              2면
#             </span>
#             <span class="date">
#              2021.05.04. 오후 8:23
#             </span>
#            </dt>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436562">
#              베이조스 44조8000억원·머독은 1조9100억원 넘겨
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 2면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              2면
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:05
#             </span>
#            </dt>
#           </dl>
#          </li>
#         </ul>
#         <h4 class="paper_h4">
#          3면
#         </h4>
#         <ul class="type13 firstlist">
#          <li>
#           <dl>
#            <dt class="photo">
#             <a class="nclicks(cnt_papaerart1)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436524">
#              <img alt="대권행보 닻 올린 이재명… 9개월째 ‘여권 1위’ 대세 굳힐까" height="90" src="https://imgnews.pstatic.net/image/origin/005/2021/05/05/1436524.jpg?type=nf132_90" width="132"/>
#             </a>
#            </dt>
#            <dt>
#             <a class="nclicks(cnt_papaerart3)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436524">
#              대권행보 닻 올린 이재명… 9개월째 ‘여권 1위’ 대세 굳힐까
#             </a>
#            </dt>
#            <dd>
#             <span class="lede 88">
#              이재명 경기지사가 ‘성장’을 내걸고 대권 경선 레이스에 본격적으로 뛰어든다. ‘기본 시리즈’로 대표되는 복지 담론에 이어 성장 담론을 통해 ‘대세론’을 굳히겠 …
#             </span>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 3면의 TOP기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              3면
#              <i class="icon_top">
#               TOP
#              </i>
#             </span>
#             <span class="date">
#              2021.05.05. 오전 12:11
#             </span>
#            </dd>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436552">
#              지자체장 ‘제약된 활동’ 넘어서기…  지지 의원 중심 외연 확장 잰걸음
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 3면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              3면
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:04
#             </span>
#            </dt>
#           </dl>
#          </li>
#         </ul>
#         <h4 class="paper_h4">
#          4면
#         </h4>
#         <ul class="type13 firstlist">
#          <li>
#           <dl>
#            <dt class="photo">
#             <a class="nclicks(cnt_papaerart1)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436554">
#              <img alt="노형욱 “보유세 단계적 완화 검토… 공시가격 현실화 계획대로”" height="90" src="https://imgnews.pstatic.net/image/origin/005/2021/05/05/1436554.jpg?type=nf132_90" width="132"/>
#             </a>
#            </dt>
#            <dt>
#             <a class="nclicks(cnt_papaerart3)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436554">
#              노형욱 “보유세 단계적 완화 검토… 공시가격 현실화 계획대로”
#             </a>
#            </dt>
#            <dd>
#             <span class="lede 88">
#              노형욱 국토교통부 장관 후보자가 최근 공시가격 급등 논란과 관련해 “공시가격 현실화는 계획대로 추진하되, 주택 보유 부담은 단계적으로 완화하는 방안을 검토하겠 …
#             </span>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 4면의 TOP기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              4면
#              <i class="icon_top">
#               TOP
#              </i>
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:04
#             </span>
#            </dd>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436597">
#              문승욱 “탈원전 정책 지속돼야”… 증여세 탈루 의혹엔 “송구”
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 4면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              4면
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:09
#             </span>
#            </dt>
#           </dl>
#          </li>
#         </ul>
#         <h4 class="paper_h4">
#          5면
#         </h4>
#         <ul class="type13 firstlist">
#          <li>
#           <dl>
#            <dt class="photo">
#             <a class="nclicks(cnt_papaerart1)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436559">
#              <img alt="국민의힘, 당권 레이스 본격화되자 ‘지역주의 프레임’ 또 표출" height="90" src="https://imgnews.pstatic.net/image/origin/005/2021/05/05/1436559.jpg?type=nf132_90" width="132"/>
#             </a>
#            </dt>
#            <dt>
#             <a class="nclicks(cnt_papaerart3)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436559">
#              국민의힘, 당권 레이스 본격화되자 ‘지역주의 프레임’ 또 표출
#             </a>
#            </dt>
#            <dd>
#             <span class="lede 88">
#              국민의힘 차기 당권 경쟁이 본격화되면서 ‘영남당 논란’이 주요 쟁점으로 떠올랐다. 2년 전 당대표 경선 때만 해도 ‘친박 대 친이’ 같은 계파 대립이 기승을  …
#             </span>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 5면의 TOP기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              5면
#              <i class="icon_top">
#               TOP
#              </i>
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:04
#             </span>
#            </dd>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436575">
#              송영길, 부동산 정책 속도전 돌입
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 5면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              5면
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:07
#             </span>
#            </dt>
#           </dl>
#          </li>
#         </ul>
#         <h4 class="paper_h4">
#          6면
#         </h4>
#         <ul class="type13 firstlist">
#          <li>
#           <dl>
#            <dt class="photo">
#             <a class="nclicks(cnt_papaerart1)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436561">
#              <img alt="‘한반도 비핵화’로 표현 바꾼 美… 우리정부 입장 일부 반영한 듯" height="90" src="https://imgnews.pstatic.net/image/origin/005/2021/05/05/1436561.jpg?type=nf132_90" width="132"/>
#             </a>
#            </dt>
#            <dt>
#             <a class="nclicks(cnt_papaerart3)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436561">
#              ‘한반도 비핵화’로 표현 바꾼 美… 우리정부 입장 일부 반영한 듯
#             </a>
#            </dt>
#            <dd>
#             <span class="lede 88">
#              출범 이후 줄곧 ‘북한 비핵화’를 고집하던 조 바이든 미국 행정부가 최근 대북정책 검토를 마친 이후 ‘한반도 비핵화’로 표현을 변경했다. 극명하게 대비되는 도 …
#             </span>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 6면의 TOP기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              6면
#              <i class="icon_top">
#               TOP
#              </i>
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:04
#             </span>
#            </dd>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436508">
#              [포토] 양대 노총 등, 日 조선인 강제노동 부정 규탄 회견
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 6면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              6면
#             </span>
#             <span class="date">
#              2021.05.04. 오후 9:36
#             </span>
#            </dt>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436557">
#              블링컨 “외교적 기회 잡으라”… 북한에 다시 공 넘겼다
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 6면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              6면
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:04
#             </span>
#            </dt>
#           </dl>
#          </li>
#         </ul>
#         <h4 class="paper_h4">
#          8면
#         </h4>
#         <ul class="type13 firstlist">
#          <li>
#           <dl>
#            <dt class="photo">
#             <a class="nclicks(cnt_papaerart1)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436518">
#              <img alt="이제 ‘변이 판데믹’ 올까… 10개 변이 공포, 백신 무력화 우려" height="90" src="https://imgnews.pstatic.net/image/origin/005/2021/05/05/1436518.jpg?type=nf132_90" width="132"/>
#             </a>
#            </dt>
#            <dt>
#             <a class="nclicks(cnt_papaerart3)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436518">
#              이제 ‘변이 판데믹’ 올까… 10개 변이 공포, 백신 무력화 우려
#             </a>
#            </dt>
#            <dd>
#             <span class="lede 88">
#              과연 백신을 맞으면 코로나19 종식이 올까. 최근 이스라엘, 영국, 미국 등 백신 접종률이 높은 국가들은 일상으로의 복귀를 서두르고 있지만 일각에선 언제든지  …
#             </span>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 8면의 TOP기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              8면
#              <i class="icon_top">
#               TOP
#              </i>
#             </span>
#             <span class="date">
#              2021.05.05. 오전 12:03
#             </span>
#            </dd>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436588">
#              백신 선진국이라던 이스라엘, 잇단 ‘변이 감염’에 발칵
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 8면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              8면
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:09
#             </span>
#            </dt>
#           </dl>
#          </li>
#         </ul>
#         <h4 class="paper_h4">
#          10면
#         </h4>
#         <ul class="type13 firstlist">
#          <li>
#           <dl>
#            <dt class="photo">
#             <a class="nclicks(cnt_papaerart1)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436574">
#              <img alt="홍 회장 사퇴 “아들에게 안 물려준다”… 불매운동 사그라들까" height="90" src="https://imgnews.pstatic.net/image/origin/005/2021/05/05/1436574.jpg?type=nf132_90" width="132"/>
#             </a>
#            </dt>
#            <dt>
#             <a class="nclicks(cnt_papaerart3)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436574">
#              홍 회장 사퇴 “아들에게 안 물려준다”… 불매운동 사그라들까
#             </a>
#            </dt>
#            <dd>
#             <span class="lede 88">
#              홍원식 남양유업 회장이 경영 일선에서 물러났다. 남양유업이 수차례 사회적 물의를 일으킨 점을 사과하면서 회장직 사퇴의 뜻을 밝힌 것이다. 홍 회장은 “두 아들 …
#             </span>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 10면의 TOP기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              10면
#              <i class="icon_top">
#               TOP
#              </i>
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:07
#             </span>
#            </dd>
#           </dl>
#          </li>
#          <li>
#           <dl>
#            <dt>
#             <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436595">
#              참여연대 “쿠팡 ‘아이템 위너’는 소비자 기만”… 공정위에 신고
#             </a>
#             <i class="icon_photo">
#              포토
#             </i>
#             <span class="writing">
#              국민일보
#             </span>
#             <span class="newspaper_info" title="신문에 게재되었으며 10면의 기사입니다.">
#              <i class="picon">
#               신문
#              </i>
#              10면
#             </span>
#             <span class="date">
#              2021.05.05. 오전 4:09
#             </span>
#            </dt>
#           </dl>
#          </li>
#         </ul>
#        </div>
#        <div class="topbox_type6">
#         <div>
#          <ul>
#           <li>
#            <a class="on nclicks(cnt_order)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210505&amp;page=1">
#             1~10면
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(cnt_order)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210505&amp;page=2">
#             11~20면
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(cnt_order)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210505&amp;page=3">
#             21~30면
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(cnt_order)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210505&amp;page=4">
#             31~40면
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="pagenavi_day pagenavi_day2">
#         <a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210506">
#          5월6일(목)
#         </a>
#         <span class="devidebar">
#          ·
#         </span>
#         <span class="viewday">
#          5월5일(수)
#         </span>
#         <span class="devidebar">
#          ·
#         </span>
#         <a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210504">
#          5월4일(화)
#         </a>
#         <span class="devidebar">
#          ·
#         </span>
#         <a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210503">
#          5월3일(월)
#         </a>
#         <span class="devidebar">
#          ·
#         </span>
#         <a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=005&amp;listType=paper&amp;date=20210501">
#          5월1일(토)
#         </a>
#        </div>
#        <script type="text/javascript">
#         window.onload = function() {
# 	var selected_item = jindo.$('_');
# 	if (selected_item != null) {
# 		selected_item.className = "highlight";
# 		news.section.ScrollingManager.scroll('');
# 	}
# }
# news.section.MainIssueCollectManager.init();
# news.util.CommentListCountManager.view();
#        </script>
#       </div>
#      </td>
#      <td class="aside">
#       <div class="aside">
#        <div class="section _officeTopRanking1087479">
#         <h4>
#          언론사별 가장 많이 본 뉴스
#         </h4>
#         <button class="section_info_icon nclicks('rig.renws2i') _rankingInfoButton" type="button">
#          안내
#         </button>
#         <div class="section_info_layer _rankingInfoLayer" style="display: none">
#          각 언론사의 가장 많이 본 기사 1건을 제공합니다.
#          <button class="section_info_layer_close _rankingInfoCloseButton nclicks('rig.renws2x')" type="button">
#           <span>
#            닫기
#           </span>
#          </button>
#         </div>
#         <p class="section_sub_txt">
#          오후 11시~오전 12시까지 집계한 결과입니다.
#         </p>
#         <ul class="section_list_ranking_press _rankingList" id="_rankingList0" style="display: block">
#          <li>
#           <a class="ranking_thumb nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=023&amp;aid=0003612209&amp;rankingType=RANKING">
#            <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/023/2021/05/05/3612209.jpg?type=nf88_60" width="88"/>
#           </a>
#           <div class="list_text_wrap">
#            <div class="list_text">
#             <div class="list_text_inner">
#              <a class="list_tit nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=023&amp;aid=0003612209&amp;rankingType=RANKING">
#               AZ 맞은 후 증상없던 50대 의사, 이틀만에 사망
#              </a>
#              <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.nhn?officeId=023">
#               <span class="list_press_thumb">
#                <img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/04/29/logo_023_56_20200429140429.png" width="16"/>
#               </span>
#               조선일보
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <a class="ranking_thumb nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=437&amp;aid=0000265529&amp;rankingType=RANKING">
#            <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/437/2021/05/05/265529.jpg?type=nf88_60" width="88"/>
#            <strong class="r_ico r_vod_small">
#             동영상기사
#            </strong>
#           </a>
#           <div class="list_text_wrap">
#            <div class="list_text">
#             <div class="list_text_inner">
#              <a class="list_tit nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=437&amp;aid=0000265529&amp;rankingType=RANKING">
#               "정민아, 넌 선물이었어" 아버지의 편지…눈물 속 발인
#              </a>
#              <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.nhn?officeId=437">
#               <span class="list_press_thumb">
#                <img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/437/2020/08/25/logo_437_56_20200825135552.png" width="16"/>
#               </span>
#               JTBC
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <a class="ranking_thumb nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=025&amp;aid=0003099280&amp;rankingType=RANKING">
#            <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/025/2021/05/05/3099280.jpg?type=nf88_60" width="88"/>
#           </a>
#           <div class="list_text_wrap">
#            <div class="list_text">
#             <div class="list_text_inner">
#              <a class="list_tit nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=025&amp;aid=0003099280&amp;rankingType=RANKING">
#               '카톡 저만 안되나요?' 채팅·로그인 먹통···카카오 "복 …
#              </a>
#              <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.nhn?officeId=025">
#               <span class="list_press_thumb">
#                <img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/025/2020/08/11/logo_025_56_20200811154627.png" width="16"/>
#               </span>
#               중앙일보
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <a class="ranking_thumb nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=056&amp;aid=0011038730&amp;rankingType=RANKING">
#            <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/056/2021/05/05/11038730.jpg?type=nf88_60" width="88"/>
#            <strong class="r_ico r_vod_small">
#             동영상기사
#            </strong>
#           </a>
#           <div class="list_text_wrap">
#            <div class="list_text">
#             <div class="list_text_inner">
#              <a class="list_tit nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=056&amp;aid=0011038730&amp;rankingType=RANKING">
#               [단독] 美 한인상점 둔기 폭행 50대 한인상점 골라 난동 …
#              </a>
#              <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.nhn?officeId=056">
#               <span class="list_press_thumb">
#                <img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/056/2018/08/01/logo_056_56_20180801152701.png" width="16"/>
#               </span>
#               KBS
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <a class="ranking_thumb nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=015&amp;aid=0004541498&amp;rankingType=RANKING">
#            <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/015/2021/05/05/4541498.jpg?type=nf88_60" width="88"/>
#           </a>
#           <div class="list_text_wrap">
#            <div class="list_text">
#             <div class="list_text_inner">
#              <a class="list_tit nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=015&amp;aid=0004541498&amp;rankingType=RANKING">
# ...
#           </a>
#           <div class="list_text_wrap">
#            <div class="list_text">
#             <div class="list_text_inner">
#              <a class="list_tit nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=648&amp;aid=0000000866&amp;rankingType=RANKING">
#               G80 뚝심…제네시스 올해 2배 더 팔렸다
#              </a>
#              <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.nhn?officeId=648">
#               <span class="list_press_thumb">
#                <img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/648/2021/04/20/logo_648_56_20210420164020.jpg" width="16"/>
#               </span>
#               비즈니스워치
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <a class="ranking_thumb nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=145&amp;aid=0000015399&amp;rankingType=RANKING">
#            <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2021/05/05/15399.jpg?type=nf88_60" width="88"/>
#           </a>
#           <div class="list_text_wrap">
#            <div class="list_text">
#             <div class="list_text_inner">
#              <a class="list_tit nclicks('rig.renws2')" href="/main/ranking/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=001&amp;oid=145&amp;aid=0000015399&amp;rankingType=RANKING">
#               [백인혜의 SNS 톡톡] 지금 당신은 안정적인 ‘N잡러’인 …
#              </a>
#              <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.nhn?officeId=145">
#               <span class="list_press_thumb">
#                <img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/>
#               </span>
#               레이디경향
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#         </ul>
#         <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">
#          더보기
#         </button>
#        </div>
#        <script type="text/javascript">
#         var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087479");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
#        </script>
#        <div class="da" id="doubleDA">
#        </div>
#        <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
#         <h4>
#          분야별 주요뉴스
#         </h4>
#         <div class="classfy sd" style="display:block">
#          <ul class="list_txt">
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=003&amp;aid=0010483662" title='"한일 외교장관회담 실현 배경엔 美의향 있는듯" 아사히'>
#             "한일 외교장관회담 실현 배경엔 美의향 있는듯" 아사히
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=081&amp;aid=0003184167" title="“대통령 할아버지 꿈은 어린이들 마스크 벗게 하는 것”">
#             “대통령 할아버지 꿈은 어린이들 마스크 벗게 하는 것”
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=003&amp;aid=0010483636" title="이재명, 50년전 초등학교 1학년 성적은?">
#             이재명, 50년전 초등학교 1학년 성적은?
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=469&amp;aid=0000602379" title="EU 인구 4분의 1, 코로나19 백신 최소 1회 접종">
#             EU 인구 4분의 1, 코로나19 백신 최소 1회 접종
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=001&amp;aid=0012375115" title="'코로나 확산' 베트남, 입국 후 격리기간 28일로 연장">
#             '코로나 확산' 베트남, 입국 후 격리기간 28일로 연장
#            </a>
#           </li>
#          </ul>
#          <ul class="list_txt">
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=021&amp;aid=0002469850" title="부처간 ‘엇박자’에…지자체 ‘수소산업 집적화 단지’ 사업 차질">
#             부처간 ‘엇박자’에…지자체 ‘수소산업 집적화 단지’ 사업 차질
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=022&amp;aid=0003578187" title="잇단 확진에 롯데百 본점은 6일 임시 휴업, 신세계百 강남점은 “휴점 검토 안했다”">
#             잇단 확진에 롯데百 본점은 6일 임시 휴업, 신세계百 강남점은 “휴점 검토 안했다”
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=018&amp;aid=0004921378" title="바이든 정부 압박 먹혔나..TSMC, 美 반도체 공장 1개→6개로 확대">
#             바이든 정부 압박 먹혔나..TSMC, 美 반도체 공장 1개→6개로 확대
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=015&amp;aid=0004541563" title="LG유플러스, IoT·드론용 5G 안테나 개발">
#             LG유플러스, IoT·드론용 5G 안테나 개발
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=008&amp;aid=0004583093" title='"카톡 하나에 대한민국이 멈췄다"…1시간 넘게 먹통'>
#             "카톡 하나에 대한민국이 멈췄다"…1시간 넘게 먹통
#            </a>
#           </li>
#          </ul>
#          <ul class="list_txt">
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=056&amp;aid=0011038625" title="복지부, “유치원-어린이집 급식비 비교 기준 다르다”">
#             복지부, “유치원-어린이집 급식비 비교 기준 다르다”
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=421&amp;aid=0005331948" title='이별통보 연인에 "아들 학교 찾아간다" 189회 연락한 30대'>
#             이별통보 연인에 "아들 학교 찾아간다" 189회 연락한 30대
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=437&amp;aid=0000265515" title='"AZ 맞은 20대 아들, 하루아침에 일상생활 불가능"'>
#             "AZ 맞은 20대 아들, 하루아침에 일상생활 불가능"
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=016&amp;aid=0001831384" title="임영웅, 흡연 논란 사과…“니코틴 함유되지 않아 담배 아니라고 생각”">
#             임영웅, 흡연 논란 사과…“니코틴 함유되지 않아 담배 아니라고 생각”
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=022&amp;aid=0003578168" title="기아 전기차 EV6 유럽서 흥행 질주 예고">
#             기아 전기차 EV6 유럽서 흥행 질주 예고
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="section">
#         <div class="banner">
#          <a class="nclicks(rig.banner)" href="http://factcheck.snu.ac.kr/documents/193" target="_blank">
#           <img alt="온라인 허위정보, 팩트체크 어떻게 확인할까요" src="https://imgnews.pstatic.net/image/upload/item/2020/02/05/175955946_%2540banner_300X80_pc.png" width="300">
#           </img>
#          </a>
#         </div>
#        </div>
#        <div class="section">
#         <div class="banner">
#          <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.nhn?mid=omb" target="_blank">
#           <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183022480_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300">
#           </img>
#          </a>
#         </div>
#        </div>
#        <div class="da" id="rightDoubleDA" style="display: none">
#        </div>
#        <script type="text/javascript">
#         try{
#                     jindo.$("doubleDA").innerHTML = '<div id="daEtc_300250" name="daEtc_300250" style="width: 300px; height: 250px;"><iframe id="etc300250" name="etc300250" src="https://veta.naver.com/fxshow?su=SU10306&calp=shome" width="300" height="250" marginheight="0" marginwidth="0" border="0" frameborder="0" scrolling="no" align="center" title="우측_기타영역_더블플레이광고" data-veta-preview="news_home_02"></iframe></div>';
#                 }catch(e){}
#        </script>
#        <div class="rightBottomDouble" style="margin-top:36px;">
#         <div data-dom-type="doubleplay_bottom" id="doubleE300250" name="doubleE300250" title="더블플레이하단광고">
#         </div>
#        </div>
#       </div>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <hr/>
#   <div class="index">
#    <div class="index_inner">
#     <div class="floating_btn">
#      <div class="floating_inner">
#       <a class="floating_btn_back" href="javascript:history.back();">
#        <span class="blind">
#         이젠 페이지
#        </span>
#       </a>
#       <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;">
#        <span class="blind">
#         맨위로
#        </span>
#       </a>
#      </div>
#     </div>
#     <div class="index_tab" id="index.press_category">
#      <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">
#       언론사 목록
#       <span class="_stit_tab_arrow stit_arrow">
#        <span class="blind">
#         열기
#        </span>
#       </span>
#       <span class="loading" style="display:none;">
#        로딩 중
#       </span>
#      </a>
#      <div class="index_content is_hidden" id="index.press.area">
#      </div>
#      <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">
#       분야별 목록
#       <span class="_stit_tab_arrow stit_arrow">
#        <span class="blind">
#         열기
#        </span>
#       </span>
#       <span class="loading" style="display:none;">
#        로딩 중
#       </span>
#      </a>
#      <div class="index_content02 is_hidden" id="index.category.area">
#      </div>
#     </div>
#     <div class="index_myscrap">
#      <a class="spr nclicks(fot.scrap)" href="/main/scrap/index.nhn">
#       마이스크랩
#      </a>
#     </div>
#    </div>
#   </div>
#   <hr/>
#   <div id="footer">
#    <ul>
#     <li class="first">
#      <a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">
#       이용약관
#      </a>
#     </li>
#     <li>
#      <a class="nclicks(fot.guide)" href="/main/ombudsman/index.nhn">
#       서비스 안내
#      </a>
#     </li>
#     <li>
#      <a class="nclicks(fot.editor)" href="/main/ombudsman/edit.nhn?mid=omb">
#       기사배열 원칙 책임자 : 유봉석
#      </a>
#     </li>
#     <li>
#      청소년 보호 책임자 : 이희만
#     </li>
#     <li>
#      <strong>
#       <a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">
#        개인정보처리방침
#       </a>
#      </strong>
#     </li>
#     <li>
#      <a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">
#       책임의 한계와 법적고지
#      </a>
#     </li>
#     <li>
#      <a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">
#       뉴스 고객센터
#      </a>
#     </li>
#    </ul>
#    <p class="copyright">
#     본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.
#    </p>
#    <address class="address_nhn">
#     <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank">
#      <span class="blind">
#       NAVER
#      </span>
#     </a>
#     <em>
#      Copyright ©
#     </em>
#     <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">
#      NAVER Corp.
#     </a>
#     <span>
#      All Rights Reserved.
#     </span>
#    </address>
#    <!-- -->
#   </div>
#   <script type="text/javascript">
#    new news.lnb.NewsSearchController('lnb.searchForm');
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.nhn'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.nhn'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
# new news.flash.SubsectionLayerManager('n.f.subsection.layer');
#
#
# new MyFeed()
#     .init({
#         sMyFeedUrl: 'https://me.naver.com/tab/feed/news.nhn',
#         apiUrlMap: {
#             'check': 'https://apis.naver.com/newsweb/media/subscribedChannels?hasFollowerCount=true',
#             'follow': 'https://apis.naver.com/newsweb/media/doSubscribe',
#             'unfollow': 'https://apis.naver.com/newsweb/media/cancelSubscribe'
#         }
#     });
#
#
#
# new news.util.Calendar({
# 	url:'/main/list.nhn?mode=LPOD&mid=sec&oid=005&listType=paper&date=',
# 	selectedDate:'2021/05/05',
# 	minDate:'2010/05/12',
# 	maxDate:'2021/05/06'
# });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#   </script>
#  </body>
# </html>

# %% [markdown]
# <hr>
#
# 크롤링한 내용을 가지고 이제 우리가 원하는 데이터만 뽑을 것이다.
#
# 데이터 파싱 테스트를 시도할 때마다 웹페이지 요청을 시도하는 불필요한 작업을 없애고,
#
# 나중에 다시 작업을 해도 데이터가 유지될 수 있도록 위에 있는 내용을 그대로 파일로 만들자.

# %%
f = open("source.html", 'w',encoding="UTF8")
f.write(soup.prettify())
f.close()

# %% [markdown]
# 이제 저장된 내용을 불러오고, 저장된 내용을 분석해 내가 원하는 데이터를 어떻게 가져올 것인지 전략을 짜야한다.

# %%
with open("source.html", 'r',encoding="UTF8") as fp:
    f_soup = BeautifulSoup(fp, 'html.parser')

# %%
parsing_test = f_soup.find_all(attrs={"class": "nclicks(cnt_papaerart4)"})
print(len(parsing_test))
parsing_test
# Out:
# 12
# [<a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436525">
#               [포토] 코로나에도… 즐거운 동심
#              </a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436596">
#               가족동반 출장엔 “관행” 밀수 의혹은 “집에서 사용”… 황당 해명
#              </a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436602">
#               변이 바이러스 국내 감염자 1499명 ‘비상’
#              </a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436497">
#               [국민만평-서민호 화백] 2021년 5월 5일
#              </a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436562">
#               베이조스 44조8000억원·머독은 1조9100억원 넘겨
#              </a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436552">
#               지자체장 ‘제약된 활동’ 넘어서기…  지지 의원 중심 외연 확장 잰걸음
#              </a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436597">
#               문승욱 “탈원전 정책 지속돼야”… 증여세 탈루 의혹엔 “송구”
#              </a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436575">
#               송영길, 부동산 정책 속도전 돌입
#              </a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436508">
#               [포토] 양대 노총 등, 日 조선인 강제노동 부정 규탄 회견
#              </a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436557">
#               블링컨 “외교적 기회 잡으라”… 북한에 다시 공 넘겼다
#              </a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436588">
#               백신 선진국이라던 이스라엘, 잇단 ‘변이 감염’에 발칵
#              </a>,
#  <a class="nclicks(cnt_papaerart4)" href="https://news.naver.com/main/read.nhn?mode=LPOD&amp;mid=sec&amp;oid=005&amp;aid=0001436595">
#               참여연대 “쿠팡 ‘아이템 위너’는 소비자 기만”… 공정위에 신고
#              </a>]

# %%
parsing_test[0].get_text()
# Out:
# '\n             [포토] 코로나에도… 즐거운 동심\n            '

# %% [markdown]
#  - 문자열 함수 `replace()`와 `strip()`을 활용하여 불필요한 문자인 개행문자(`\n`)와 공백문자(`&nbsp;`)를 없애자

# %%
parsing_test[0].get_text().replace("\n","").strip()
# Out:
# '[포토] 코로나에도… 즐거운 동심'

# %% [markdown]
#  - 각 기사 제목 옆에 링크도 매칭시켜주자

# %%
parsing_test[0]['href']
# Out:
# 'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436525'

# %%
def pairing_title_and_link(soup_data):
    result = []
    for element in soup_data:
        result.append(
            (element.get_text().replace("\n","").strip(),
            element['href'])
        )
    return result
    

matching_result = pairing_title_and_link(parsing_test)

# %%
matching_result
# Out:
# [('[포토] 코로나에도… 즐거운 동심',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436525'),
#  ('가족동반 출장엔 “관행” 밀수 의혹은 “집에서 사용”… 황당 해명',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436596'),
#  ('변이 바이러스 국내 감염자 1499명 ‘비상’',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436602'),
#  ('[국민만평-서민호 화백] 2021년 5월 5일',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436497'),
#  ('베이조스 44조8000억원·머독은 1조9100억원 넘겨',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436562'),
#  ('지자체장 ‘제약된 활동’ 넘어서기…  지지 의원 중심 외연 확장 잰걸음',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436552'),
#  ('문승욱 “탈원전 정책 지속돼야”… 증여세 탈루 의혹엔 “송구”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436597'),
#  ('송영길, 부동산 정책 속도전 돌입',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436575'),
#  ('[포토] 양대 노총 등, 日 조선인 강제노동 부정 규탄 회견',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436508'),
#  ('블링컨 “외교적 기회 잡으라”… 북한에 다시 공 넘겼다',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436557'),
#  ('백신 선진국이라던 이스라엘, 잇단 ‘변이 감염’에 발칵',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436588'),
#  ('참여연대 “쿠팡 ‘아이템 위너’는 소비자 기만”… 공정위에 신고',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436595')]

# %% [markdown]
# ## - 특정 날짜의 신문 제목과 링크들 전부 가져오기

# %% [markdown]
# ### * 네이버 신문 중 국민일보 페이지 분석 결과
#  1. 속성이 `class="nclicks(cnt_papaerart3)"`와 `class="nclicks(cnt_papaerart4)"`인 것만 찾아오면 된다.
#  2. 페이지가 초과하면 첫번째 페이지만 보여준다.
#  3. 만일 해당날짜에 발행된 신문이 없으면 `class="result_none"`가 나타난다.
#  4. 신경써야할 uri 파라미터는 아래와 같다.
#     - `oid=005` : 국민일보 식별번호
#     - `data=20210505` : 신문발행 날짜
#     - `page=1` : 신문 페이지

# %% [markdown]
# ### * 필요한 모듈 가져오기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## * 함수 정의부

# %%
def make_url(url_info):
    return '{address}?mode={mode}&mid={mid}&oid={oid}&listType={listType}&date={date}&page={page}'.format(**url_info)
    
def pairing_title_and_link(soup_data):
    result = []
    for element in soup_data:
        result.append(
            (element.get_text().replace("\n","").strip(),
            element['href'])
        )
    return result

def flatten(vec_data):
    return [num for elem in vec_data for num in elem]

# %% [markdown]
# ### * 주요 변수 정의부

# %%
headers = { "User-Agent": "user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36" } 

url_info = dict(
    address = "https://news.naver.com/main/list.nhn",
    mode='LPOD',
    mid='sec',
    oid='005',
    listType='paper',
    date='20210505'
)#page는 크롤링을 실행하면서 결정

# %% [markdown]
# ### * 크롤링 실행부

# %%
page = 1
first_page_first_title = ''
isFirstPage = True
result_content = []

while True:
    #크롤링 준비
    url_info['page'] = page
    url = make_url(url_info)
    page += 1
    
    #크롤링 진행
    webpage = requests.get(url, headers=headers)
    soup = BeautifulSoup(webpage.text, 'html.parser')
    parsing_data = soup.find_all(attrs={'class': ["nclicks(cnt_papaerart3)", "nclicks(cnt_papaerart4)"]})
    pairing_data = pairing_title_and_link(parsing_data)
    
    
    #크롤링 이후 데이터 평가
    if isFirstPage:
        first_page_first_title = pairing_data[0][0]
        isFirstPage = False
    else:
        if first_page_first_title == pairing_data[0][0]:
            print("페이지 모두 읽기 완료")
            break
    
    #크롤링 데이터 저장
    result_content.append(pairing_data)
    
print("크롤링 종료")
# Out:
# 페이지 모두 읽기 완료
# 크롤링 종료

# %% [markdown]
# ### * 크롤링 후처리

# %%
result_content = flatten(result_content)

#파일로 저장
f = open("result_content.txt", 'w',encoding="UTF8")
for ele in result_content:
    f.write(ele[0] + "   ---   " + ele[1] + "\n")
f.close()

# %%
len(result_content)
# Out:
# 94

# %%
result_content
# Out:
# [('후보 확정까지 4개월… 대선 행보 초읽기',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436553'),
#  ('[포토] 코로나에도… 즐거운 동심',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436525'),
#  ('가족동반 출장엔 “관행” 밀수 의혹은 “집에서 사용”… 황당 해명',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436596'),
#  ('변이 바이러스 국내 감염자 1499명 ‘비상’',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436602'),
#  ('27년 동행 끝 ‘천문학적 결별’… 재산 146조 어떻게 나눌까',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436555'),
#  ('[국민만평-서민호 화백] 2021년 5월 5일',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436497'),
#  ('베이조스 44조8000억원·머독은 1조9100억원 넘겨',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436562'),
#  ('대권행보 닻 올린 이재명… 9개월째 ‘여권 1위’ 대세 굳힐까',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436524'),
#  ('지자체장 ‘제약된 활동’ 넘어서기…  지지 의원 중심 외연 확장 잰걸음',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436552'),
#  ('노형욱 “보유세 단계적 완화 검토… 공시가격 현실화 계획대로”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436554'),
#  ('문승욱 “탈원전 정책 지속돼야”… 증여세 탈루 의혹엔 “송구”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436597'),
#  ('국민의힘, 당권 레이스 본격화되자 ‘지역주의 프레임’ 또 표출',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436559'),
#  ('송영길, 부동산 정책 속도전 돌입',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436575'),
#  ('‘한반도 비핵화’로 표현 바꾼 美… 우리정부 입장 일부 반영한 듯',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436561'),
#  ('[포토] 양대 노총 등, 日 조선인 강제노동 부정 규탄 회견',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436508'),
#  ('블링컨 “외교적 기회 잡으라”… 북한에 다시 공 넘겼다',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436557'),
#  ('이제 ‘변이 판데믹’ 올까… 10개 변이 공포, 백신 무력화 우려',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436518'),
#  ('백신 선진국이라던 이스라엘, 잇단 ‘변이 감염’에 발칵',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436588'),
#  ('홍 회장 사퇴 “아들에게 안 물려준다”… 불매운동 사그라들까',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436574'),
#  ('참여연대 “쿠팡 ‘아이템 위너’는 소비자 기만”… 공정위에 신고',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436595'),
#  ('‘조직 안정’ 내건 총장후보… 檢 “인사 정상화가 관건”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436566'),
#  ('경찰, 공수처 사무규칙 공포에 “몰랐다”… 엇갈린 평가',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436573'),
#  ('[포토] 금융소비자연맹, 펀드매니저 사칭 채널 방치한 카카오 고발',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436511'),
#  ('檢 내부선 “공수처 사무규칙, 규칙에 불과… 따를 의무 없다”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436565'),
#  ('“제발 안 아픈 주사로” 혈우병 아이 엄마들 눈물의 어린이날',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436519'),
#  ('[포토] 정인이를 추모하며',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436513'),
#  ('사회 양극화 종합적 파악 ‘사회통합지표’ 만든다',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436582'),
#  ('2026년부턴 임용 경력기준 10년… 판사 부족현상 심화 우려',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436560'),
#  ('[포토] 차세대 중형위성 1호가 촬영한 우리땅 독도',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436510'),
#  ('‘한강 사망 의대생’ 인근서 발견된 휴대전화 친구 것 아냐',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436576'),
#  ('문 대통령, ‘비판 전단 배포’ 고소 취하 지시',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436594'),
#  ('코로나 악재 속에서도… 경기도, 131조 투자유치했다',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436571'),
#  ('[포토] 원주한지문화제에 걸린 오색등',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436500'),
#  ('[포토] 제주행 항공편 결항 속출로 붐비는 김포공항',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436501'),
#  ('“가정의 달 5월… ‘청정 전남’서 가족과 안심여행 즐기세요”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436570'),
#  ('“군부대, 문중 땅 4만5000㎡ 66년간 무단 점유… 돌려달라”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436572'),
#  ('“코로나 시대에 맞게  축제의 모습도 변화”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436579'),
#  ('충북, 1만명에 ‘코로나 자가검사 키트’',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436580'),
#  ('출근·수업 빼먹고 대학원 다니는 교사들 많다',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436586'),
#  ('전북대·KIST 교수 10명 공동 연구',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436591'),
#  ('양천구, 서울 첫 ‘환경미화원→환경공무관’ 명칭 변경',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436592'),
#  ('“2명 중 1명 코로나 우울감  10명 중 4명 금전 스트레스”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436600'),
#  ('4월 소비자물가 44개월 만에 최대 ↑… 커지는 인플레 우려',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436546'),
#  ('‘공매도 재개? 흥!’ 증시 돈 빼 코인 갔나… 암호화폐 거래 급등',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436523'),
#  ('금통위원들 “백신 불확실성, 경제 악영향 우려”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436593'),
#  ('SKT, 2조6000억 규모 자사주 소각… 삼성전자 이어 최대',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436549'),
#  ('[포토] “무더위 날려줄 냉방 가전제품 준비하세요”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436512'),
#  ('실수요자, 아파트 포기 빌라로 몰린다',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436564'),
#  ('기아, 연비 18km/ℓ ‘K8 하이브리드’ 출시',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436577'),
#  ('탈원전에 멍든 두산重, 수소사업 다각화 ‘속도’',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436598'),
#  ('제네시스, G80 등 앞세워 유럽 고급차 시장 공략한다',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436583'),
#  ('[포토] LG, ‘클로이 서브봇’ 실내 배달 서비스 확대',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436514'),
#  ('두산건설 ‘위브더제니스 양산’ 분양',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436584'),
#  ('인천공항, 이스라엘 IAI 화물기 개조 시설 만든다',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436585'),
#  ('가정의 달 맞아 어린이·고령층 정조준한 보험 상품 ‘봇물’',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436504'),
#  ('체험 중심 공연·지재권 사업·해외 마케팅… 공연계에 새바람',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436568'),
#  ('진격 KGC-반격 KCC  두 번째 ‘왕좌의 게임’',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436589'),
#  ('한번 삐긋 땐 순위 요동… K리그2 ‘승점 전쟁’',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436590'),
#  ('선진배구 맛들린 대한항공, 새감독에 34세 틸리카이넨',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436601'),
#  ('‘잠실 더비’ ‘영호남 더비’… 어린이들 신났네',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436550'),
#  ('버핏, 후계자로 그레그 아벨 지명 “혁신적 인물”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436548'),
#  ('[인사] 금융위원회',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436505'),
#  ('[부고] 유영선씨 별세',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436506'),
#  ('농심, 백혈병소아암협회에 어린이날 선물세트 600개 전달',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436558'),
#  ('LG유플러스, 소아암 환아들에게 어린이날 선물',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436563'),
#  ('권순학 경북대 어린이병원장, 어린이날 훈장 받아',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436569'),
#  ('BGF복지재단, 주말에도 결식아동 식사 지원',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436581'),
#  ('김봉진 의장, 저소득층 학생에 150억 상당 노트북 1만대 지원',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436587'),
#  ('제주항공, 객실승무원이 짠 애착인형 보육원 전달',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436599'),
#  ('DL이앤씨, 국내 건설사 최초로 기후변화 TCFD 서포터즈 가입',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436603'),
#  ('[앵글속 세상] “새 주인 찾아주시개…” 아픈 기억 씻고 犬생역전 꿈',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436507'),
#  ('[너섬情談] 포스트 코로나를 말할 때',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436545'),
#  ('[살며 사랑하며] 가격은 손님이 정하세요',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436567'),
#  ('[이흥우 칼럼] ‘개혁의 역설’에 빠지다',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436606'),
#  ('[특파원 코너] 백신 외교에 따라붙는 일대일로',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436578'),
#  ('[사설] 임혜숙·박준영 후보자는 자진 사퇴하라',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436544'),
#  ('[사설] 외교에 방점 찍은 미국… 김정은, 기회 놓치지 말아야',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436547'),
#  ('[사설] 남양유업 회장 퇴진은 자업자득, 재계 반면교사 삼길',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436551'),
#  ('[청사초롱] 부부유별은 性 윤리다',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436556'),
#  ('[한마당] 코로나 인플레이션',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436604'),
#  ('“자기와 제일 가까운 이웃, 자신과 대화 나누는 노력 중요”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436531'),
#  ('교회가 없어진다면 교인보다 이웃들이 아쉬워할까',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436533'),
#  ('미얀마 유학생과 함께 ‘민주주의 회복’ 간절히 기도',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436538'),
#  ('[겨자씨] 우리는 언제나',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436541'),
#  ('오늘의 QT (2021.5.5)',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436542'),
#  ('‘이단 바로알기’ 한국어·영어·중국어로 출간',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436543'),
#  ('[녹색교회-보시기에 좋았더라] 창조세계 돌보는 건 인간의 의무… 보수·진보 초월해 연합해야',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436532'),
#  ('[송태근 목사의 묵상 일침] 어린이라는 세계',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436535'),
#  ('“전통적 가족 가치 부정… 건강가정기본계획 반대”',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436537'),
#  ('행동하는프로라이프, 월·목요일마다 태아생명 보호 촉구 차량 시위',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436540'),
#  ('세대잇기 실패하면… 30년 후 교회 70% 문 닫는다',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436536'),
#  ('[역경의 열매] 홍성훈 (13) 오르간이 내는 성령의 바람 소리, 또 하나의 전도',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436530'),
#  ('[가정예배 365-5월 5일] 야곱의 축복',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436534'),
#  ('[윤창재 목사의 ‘생명 설교’] 예수님을 생각나게 하는 사람',
#   'https://news.naver.com/main/read.nhn?mode=LPOD&mid=sec&oid=005&aid=0001436539')]

# %% [markdown]
# ## - 관련된 신문 제목만 크롤링하기

# %% [markdown]
# ### * 필요한 모듈 가져오기

# %%
import requests
from bs4 import BeautifulSoup

# 특정 키워드가 포함된 제목만 가져오기 위해 정규표현식 모듈 사용
import re

# %% [markdown]
# ## * 함수 정의부

# %%
def make_url(url_info):
    return '{address}?mode={mode}&mid={mid}&oid={oid}&listType={listType}&date={date}&page={page}'.format(**url_info)
    
def pairing_title_and_link(soup_data):
    result = []
    for element in soup_data:
        result.append(
            (element.get_text().replace("\n","").strip(),
            element['href'])
        )
    return result

def flatten(vec_data):
    return [num for elem in vec_data for num in elem]

# %% [markdown]
# ### * 주요 변수 정의부

# %%
headers = { "User-Agent": "user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36" } 

url_info = dict(
    address = "https://news.naver.com/main/list.nhn",
    mode='LPOD',
    mid='sec',
    oid='005',
    listType='paper',
    date='20210505'
)#page는 크롤링을 실행하면서 결정

keywords = ["북한","백신","코로나"]

# %% [markdown]
# ### * 크롤링 실행부

# %%
page = 1
first_page_first_title = ''
isFirstPage = True
result_content = []
pattern = re.compile("|".join(keywords))

while True:
    #크롤링 준비
    url_info['page'] = page
    url = make_url(url_info)
    page += 1
    
    #크롤링 진행
    webpage = requests.get(url, headers=headers)
    soup = BeautifulSoup(webpage.text, 'html.parser')
    parsing_data = soup.find_all(attrs={'class': ["nclicks(cnt_papaerart3)", "nclicks(cnt_papaerart4)"]})
    pairing_data = pairing_title_and_link(parsing_data)
    
    
    #크롤링 이후 데이터 평가
    if isFirstPage:
        first_page_first_title = pairing_data[0][0]
        isFirstPage = False
    else:
        if first_page_first_title == pairing_data[0][0]:
            print("페이지 모두 읽기 완료")
            break
    
    #크롤링 데이터 저장
    result_content.append(pairing_data)
    
print("크롤링 종료")
# Out:
# 페이지 모두 읽기 완료
# 크롤링 종료

# %% [markdown]
# ### * 크롤링 후처리

# %%
result_content = flatten(result_content)

# %%
# 키워드에 포함된 것만 고르기
result_content_by_keywords = []

for element in result_content:
    match = pattern.search(element[0])
    if match != None:
        result_content_by_keywords.append(element)

# %%
#파일로 저장
f = open("result_content_by_keywords.txt", 'w',encoding="UTF8")
for ele in result_content_by_keywords:
    f.write(ele[0] + "   ---   " + ele[1] + "\n")
f.close()

# %%
result_content_by_keywords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-41bc4f34885d> in <module>
# ----> 1 result_content_by_keywords
#
# NameError: name 'result_content_by_keywords' is not defined

# %%
import requests
url = "http://thespservices.com"
data = {'name': '김미현', 'number': 'P160015366640'}

# %%
webpage = requests.post(url, data=data)

print(webpage)
# Out:
# <Response [200]>

# %%
webpage.text
# Out:
# '<!DOCTYPE html><html><head><!-- Global site tag (gtag.js) - Google Analytics -->\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-154975073-1"></script>\n<script><window class="dataLayer">= window.dataLayer || [];</window><function>gtag(){dataLayer.push(arguments);}</function><gtag js new Date()></gtag><gtag config UA-154975073-1></gtag></script><style>body{\n    background-color: #1AAB8A;\n}\n.container {\n    position:absolute; \n    top:50%; left:50%;\n    margin-top:-225px; margin-left:-150px; \n    width:300px; height:300px;\n    text-align: center;\n}\n.form_container form{\n    width: 100%;\n    display:flex;\n    flex-direction: column;\n}\np {\n    font-size: 1.2em;\n    font-weight: 700;\n}\n.input {\n    padding: 10px 15px 10px 15px;\n    margin: 5px 10px;\n    border: 2px solid black;\n    border-radius: 5px;\n    text-decoration: none;\n    text-align: center;\n    font-size: 1.1em;\n    outline:none;\n}\n.submit{\n    margin-top: 20px;\n    background:#1AAB8A;\n    color:#fff;\n    border:black 2px solid;\n    border-radius: 10px;\n    position:relative;\n    height:60px;\n    font-size:1.4em;\n    cursor:pointer;\n    transition:400ms ease all;\n    outline:none;\n}\n.submit:hover{\n    background:#fff;\n    color:#1AAB8A;\n}\n.resultBox{\n    display: flex;\n    flex-direction: column;\n    margin-top: 20px;\n}\n.message{\n    font-size: 1.2em;\n    font-weight: 700;\n}\n.message.true{\n    color: blue;\n}\n.footer {\n    position:absolute;\n    bottom:0;\n    width:100%;\n    height:70px;\n    text-align: center;\n}</style></head><body><div class="container"> <p>개인통관고유부호 조회 서비스</p><div class="form_container"><form action="/" method="post"><input class="input" type="text" placeholder="이름을 입력하세요" name="name" requierd><input class="input" type="text" placeholder="개인통관 고유부호" name="number" requierd><input class="submit" type="submit" value="확인하기"></form></div><div class="resultBox"><label class="message true">이름과 개인통관고유부호가 일치합니다.</label></div></div><div class="footer"><p>Copyright 2019. armenpo. All rights reserved</p></div></body></html>'

# %%
requests.get("https://datalab.naver.com/shoppingInsight/sCategory.naver")
# Out:
# <Response [200]>
